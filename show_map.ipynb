# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd


from matplotlib.ticker import PercentFormatter
plt.rcParams.update({ "figure.figsize" : (8, 5),"axes.facecolor" : "white", "axes.edgecolor":  "black"})
plt.rcParams["figure.facecolor"]= "w"
pd.plotting.register_matplotlib_converters()
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
plz_shape_df = gpd.read_file('data/Zipcodes/Zipcodes_for_King_County_and_Surrounding_Area_(Shorelines)___zipcode_shore_area.shp')
fig, ax = plt.subplots()
plz_shape_df.plot(ax=ax)
plz_shape_df[plz_shape_df.ZIP == 98178].plot(ax=ax,color = 'red')
# Out:
# <AxesSubplot: >

# %%
plz_shape_df
# Out:
#      OBJECTID    ZIP ZIPCODE COUNTY  ZIP_TYPE       COUNTY_NAM  \
# 0           1  98001   98001    033  Standard      King County
# 1           2  98002   98002    033  Standard      King County
# 2           3  98003   98003    033  Standard      King County
# 3           4  98004   98004    033  Standard      King County
# 4           5  98005   98005    033  Standard      King County
# ..        ...    ...     ...    ...       ...              ...
# 204       205  98940   98940    037    PO Box  Kittitas County
# 205       206  98941   98941    037    PO Box  Kittitas County
# 206       207  98943   98943    037    PO Box  Kittitas County
# 207       208  98946   98946    037  Standard  Kittitas County
# 208       209  98950   98950    037    PO Box  Kittitas County
#
#          PREFERRED_  Shape_Leng     Shape_Area  \
# 0            AUBURN  148134.771  526121353.974
# 1            AUBURN  105168.477  204445228.298
# 2       FEDERAL WAY  121645.070  316981231.585
# ...
